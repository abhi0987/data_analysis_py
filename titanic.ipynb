# %%
import pandas as pd
import matplotlib.pyplot as plt

#read data from train.csv
#Put Your train.csv according to your directory
#In my case 'E:/Github_dir/data_analysis_py/train.csv'
df = pd.read_csv('E:/Github_dir/data_analysis_py/train.csv',header=0);
#show first 10 data
df[:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#import seaborn for visualization
import seaborn as sns
# %matplotlib inline

#plot showing population by gender
sns.factorplot('Sex',data=df,kind='count')

# %%
#plot showing population by gender in Each class (0,1,2)
sns.factorplot('Sex',data=df,hue='Pclass',kind='count')

# %%
sns.factorplot('Pclass',data=df,hue='Sex',kind='count')

# %%
#creating a coloumn 'Person' which shows if the person is male,female or child
def gender_checker(passenger):
    age,sex = passenger
    if age < 18 :
        return 'Child'
    else:
        return sex
    
df['Person'] = df[['Age','Sex']].apply(gender_checker,axis=1)

# %%
df[:50][df['Person']=='Child'][['Name','Person','Sex','Pclass']]
# Out:
# E:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#                                         Name Person     Sex  Pclass
# 7             Palsson, Master. Gosta Leonard  Child    male       3
# 9        Nasser, Mrs. Nicholas (Adele Achem)  Child  female       2
# 10           Sandstrom, Miss. Marguerite Rut  Child  female       3
# 14      Vestrom, Miss. Hulda Amanda Adolfina  Child  female       3
# 16                      Rice, Master. Eugene  Child    male       3
# 22               McGowan, Miss. Anna "Annie"  Child  female       3
# 24             Palsson, Miss. Torborg Danira  Child  female       3
# 39               Nicola-Yarred, Miss. Jamila  Child  female       3
# 43  Laroche, Miss. Simonne Marie Anne Andree  Child  female       2

# %%
#plot showing Person coloumn with hue Pclass
sns.factorplot('Person',data=df,hue='Pclass',kind='count')

# %%
#histogram representaion of age wise
df['Age'].hist(bins=70)
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Person'].value_counts()
# Out:
# male      519
# female    259
# Child     113
# Name: Person, dtype: int64

# %%
df[:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
sns.factorplot('Embarked',data=df,hue='Pclass',kind='count',order=['C','Q','S'])

# %%
df[:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#create a coloumn which shows if the passenger is alone or with family
#by adding SibSp and Parch coloumn
df['Alone'] = df.SibSp + df.Parch

# %%
df['Alone'][:10]
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    0
# 7    4
# 8    2
# 9    1
# Name: Alone, dtype: int64

# %%
# if 0 alone , if >0 with family
# assigning it to th dataframe
df['Alone'].loc[df['Alone']>0]=1
df['Alone'].loc[df['Alone']==0]=0
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df[:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#You can choose the palette from below link
# http://matplotlib.org/users/colormaps.html

#plot 'Person' v/s 'Survived' 
sns.factorplot('Person',data=df,hue='Survived',kind='count',palette='plasma')

# %%
#plot 'Alone'  v/s 'Survived' 
sns.factorplot('Alone',data=df,hue='Survived',kind='count',palette='cool')

#You can experiment with diffrent coloumns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person  Alone
# 0      0         A/5 21171   7.2500   NaN        S    male      1
# 1      0          PC 17599  71.2833   C85        C  female      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female      0
# ...

# %%
#Creating Susrviver coloumn based on Survived coloumn

sns.factorplot('Survived',data=df,hue='Alone',kind='count',palette='Set1')

# %%
sns.factorplot('Pclass','Survived',hue='Person',data=df)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person  Alone
# 0      0         A/5 21171   7.2500   NaN        S    male      1
# 1      0          PC 17599  71.2833   C85        C  female      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female      0
# ...

# %%
#Age vs survival plot differentiating with gender
#line plot
sns.lmplot('Age','Survived',hue='Sex',data=df,palette='hsv')

# %%
gen=[10,20,40,60,80]
sns.lmplot('Age','Survived',hue='Pclass',data=df,palette='hsv',x_bins=gen)

# %%
sns.lmplot('Age','Survived',hue='Sex',data=df,palette='hsv',x_bins=gen)

# %%
sns.factorplot('Survived',data=df,kind='count',hue='Alone')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person  Alone
# 0      0         A/5 21171   7.2500   NaN        S    male      1
# 1      0          PC 17599  71.2833   C85        C  female      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female      0
# ...

# %%
fig = sns.FacetGrid(data=df,hue='Survived',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)
oldest = df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()
df.head()
#Showing the surviver graph
#Survival rate of 15-30 years passengers are low
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person  Alone
# 0      0         A/5 21171   7.2500   NaN        S    male      1
# 1      0          PC 17599  71.2833   C85        C  female      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female      0
# ...

# %%
fig = sns.FacetGrid(data=df,col='Person',row='Survived',size=2.2,aspect=1.6)
fig.map(plt.hist,'Age',alpha=0.5,bins=20,color='G')

fig.add_legend()

# %%
grid = sns.FacetGrid(data=df,row='Embarked',col='Survived',size=2.2,aspect=1.6)
grid.map(sns.barplot,'Person','Fare',alpha=0.5,color='R',ci=None)
grid.add_legend()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person  Alone
# 0      0         A/5 21171   7.2500   NaN        S    male      1
# 1      0          PC 17599  71.2833   C85        C  female      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female      0
# ...

# %%
g = sns.FacetGrid(df, col='Survived')
g.map(plt.hist, 'Age', bins=20)

# %%
#Drop Ticket and Cabin coloumn
#By dropping features we are dealing with fewer data points. Speeds up our notebook and eases the analysis.
df = df.drop(['Ticket','Cabin'],axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  Person  Alone
# 0      0   7.2500        S    male      1
# 1      0  71.2833        C  female      1
# 2      0   7.9250        S  female      0
# 3      0  53.1000        S  female      1
# 4      0   8.0500        S    male      0

# %%
#analyzing if name feature can be used extract titles 
#To see the correlation b/w title and survived
#Use Regex to extract the title like (Mr.,Miss. etc)
for data in df:
    df['Title'] = df.Name.str.extract(' ([A-Za-z]+)\.',expand=False)

pd.crosstab(df['Title'],df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
#Plot showing title vs Survived 
sns.factorplot('Survived',data=df,hue='Title',kind='count',palette='Set1',size=6.0,aspect=1.6)
df[:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#A Histogram representation of Survived , Title With respect to  Age
fig = sns.FacetGrid(data=df,col='Survived',row='Title',size=2.2,aspect=1.6)
fig.map(plt.hist,'Age',alpha=0.5,bins=20,color='G')

# %%
# Replacing  all Minor titles to a single title 'Rare' 

rare = ['Capt','Col','Countess','Don','Dr','Jonkheer','Lady','Major','Rev', 'Sir']   
df['Title'] = df['Title'].replace(rare,'Rare')

# Some other conversion
df['Title'] = df['Title'].replace('Mlle','Miss')
df['Title'] = df['Title'].replace('Ms','Miss')
df['Title'] = df['Title'].replace('Mme','Mrs')

df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %%
#Plot of new Title coloumn vs Survived
#Male survival rate are low from the below graph
sns.factorplot('Survived',data=df,hue='Title',kind='count',palette='Set1',size=5.0,aspect=1.6)

# %%
# Histogram representation
fig = sns.FacetGrid(data=df,col='Title',row='Survived',size=3.2,aspect=1.6)
fig.map(plt.hist,'Age',alpha=0.5,bins=20,color='B')

# %%
df = df.drop(['Name','PassengerId'],axis=1)
df[:10]
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Person  \
# 0         0       3    male  22.0      1      0   7.2500        S    male
# 1         1       1  female  38.0      1      0  71.2833        C  female
# 2         1       3  female  26.0      0      0   7.9250        S  female
# 3         1       1  female  35.0      1      0  53.1000        S  female
# 4         0       3    male  35.0      0      0   8.0500        S    male
# 5         0       3    male   NaN      0      0   8.4583        Q    male
# 6         0       1    male  54.0      0      0  51.8625        S    male
# 7         0       3    male   2.0      3      1  21.0750        S   Child
# 8         1       3  female  27.0      0      2  11.1333        S  female
# 9         1       2  female  14.0      1      0  30.0708        C   Child
#
#    Alone   Title
# 0      1      Mr
# 1      1     Mrs
# 2      0    Miss
# 3      1     Mrs
# 4      0      Mr
# 5      0      Mr
# 6      0      Mr
# ...

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
df['Title'] = df['Title'].map(title_mapping)
df['Title'] = df['Title'].fillna(0)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Person  \
# 0         0       3    male  22.0      1      0   7.2500        S    male
# 1         1       1  female  38.0      1      0  71.2833        C  female
# 2         1       3  female  26.0      0      0   7.9250        S  female
# 3         1       1  female  35.0      1      0  53.1000        S  female
# 4         0       3    male  35.0      0      0   8.0500        S    male
#
#    Alone  Title
# 0      1      1
# 1      1      3
# 2      0      2
# 3      1      3
# 4      0      1

# %%
gender_mapping = {"female": 1, "male": 0}
df['Sex'] = df['Sex'].map(gender_mapping).astype(int)

# %%
df[:10]
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Person  Alone  \
# 0         0       3    0  22.0      1      0   7.2500        S    male      1
# 1         1       1    1  38.0      1      0  71.2833        C  female      1
# 2         1       3    1  26.0      0      0   7.9250        S  female      0
# 3         1       1    1  35.0      1      0  53.1000        S  female      1
# 4         0       3    0  35.0      0      0   8.0500        S    male      0
# 5         0       3    0   NaN      0      0   8.4583        Q    male      0
# 6         0       1    0  54.0      0      0  51.8625        S    male      0
# 7         0       3    0   2.0      3      1  21.0750        S   Child      1
# 8         1       3    1  27.0      0      2  11.1333        S  female      1
# 9         1       2    1  14.0      1      0  30.0708        C   Child      1
#
#    Title
# 0      1
# 1      3
# 2      2
# 3      3
# 4      1
# 5      1
# 6      1
# 7      4
# 8      3
# ...

# %%
gender_mapping = {"female": 1, "male": 0,"Child": 2}
df['Person'] = df['Person'].map(gender_mapping).astype(int)

# %%
df[:10]
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Person  Alone  \
# 0         0       3    0  22.0      1      0   7.2500        S       0      1
# 1         1       1    1  38.0      1      0  71.2833        C       1      1
# 2         1       3    1  26.0      0      0   7.9250        S       1      0
# 3         1       1    1  35.0      1      0  53.1000        S       1      1
# 4         0       3    0  35.0      0      0   8.0500        S       0      0
# 5         0       3    0   NaN      0      0   8.4583        Q       0      0
# 6         0       1    0  54.0      0      0  51.8625        S       0      0
# 7         0       3    0   2.0      3      1  21.0750        S       2      1
# 8         1       3    1  27.0      0      2  11.1333        S       1      1
# 9         1       2    1  14.0      1      0  30.0708        C       2      1
#
#    Title
# 0      1
# 1      3
# 2      2
# 3      3
# 4      1
# 5      1
# 6      1
# 7      4
# 8      3
# ...

# %%
#convert embarked into binary variable
#S : 0 , C : 1 , Q: 2

df.loc[df["Embarked"] == "S", "Embarked"] = 0
df.loc[df["Embarked"] == "C", "Embarked"] = 1
df.loc[df["Embarked"] == "Q", "Embarked"] = 2


#emb_map = {'S':0,'C':1,'Q':2}
#df['Embarked'] = df['Embarked'].map(emb_map)

# %%
df[:10]
#All our coloumns are in binary format
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Person  Alone  \
# 0         0       3    0  22.0      1      0   7.2500        0       0      1
# 1         1       1    1  38.0      1      0  71.2833        1       1      1
# 2         1       3    1  26.0      0      0   7.9250        0       1      0
# 3         1       1    1  35.0      1      0  53.1000        0       1      1
# 4         0       3    0  35.0      0      0   8.0500        0       0      0
# 5         0       3    0   NaN      0      0   8.4583        2       0      0
# 6         0       1    0  54.0      0      0  51.8625        0       0      0
# 7         0       3    0   2.0      3      1  21.0750        0       2      1
# 8         1       3    1  27.0      0      2  11.1333        0       1      1
# 9         1       2    1  14.0      1      0  30.0708        1       2      1
#
#    Title
# 0      1
# 1      3
# 2      2
# 3      3
# 4      1
# 5      1
# 6      1
# 7      4
# 8      3
# ...

# %%
#Calculate the median value of Age column
age_median = df['Age'].median()

# %%
age_median
# Out:
# 28.0

# %%
#Replace the null values in Age column with median value
df['Age'].fillna(age_median,inplace=True)

# %%
#Get the null embarked value
df[df['Embarked'].isnull()].head()
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch  Fare Embarked  Person  Alone  \
# 61          1       1    1  38.0      0      0  80.0      NaN       1      0
# 829         1       1    1  62.0      0      0  80.0      NaN       1      0
#
#      Title
# 61       2
# 829      3

# %%
#Replace the null values with '0' that is 'S'
df['Embarked'].fillna(0,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Person  \
# 0         0       3    0  22.0      1      0   7.2500         0       0
# 1         1       1    1  38.0      1      0  71.2833         1       1
# 2         1       3    1  26.0      0      0   7.9250         0       1
# 3         1       1    1  35.0      1      0  53.1000         0       1
# 4         0       3    0  35.0      0      0   8.0500         0       0
#
#    Alone  Title
# 0      1      1
# 1      1      3
# 2      0      2
# 3      1      3
# 4      0      1

# %%
#These are the predictive columns 
predictors_cols = ["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]

# %%
#Getting the test data
test_df = pd.read_csv('E:/Github_dir/data_analysis_py/test.csv',header=0);

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Replace  Age value as per the train data  and replace null value to median of df['Age'].median()
#Replace Sex value to binary format as per the train data
#Replace Embarked value S:0,C:1,Q:2 and also replace null value with 0
#Replace Null values in Fare coloumn with median value

# %%
test_df['Age'] = test_df['Age'].fillna(df['Age'].median())
test_df['Fare'] = test_df['Fare'].fillna(test_df['Fare'].median())
gender_mapping_ = {"female": 1, "male": 0}
test_df['Sex'] = test_df['Sex'].map(gender_mapping_).astype(int)
embarked_mapping_ = {"S": 0, "C": 1,"Q":2}
test_df['Embarked'] = test_df['Embarked'].map(embarked_mapping_).astype(int)
test_df['Embarked'].fillna(0,inplace=True)

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2          894       2                     Myles, Mr. Thomas Francis    0
# 3          895       3                              Wirz, Mr. Albert    0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
#
#     Age  SibSp  Parch   Ticket     Fare Cabin  Embarked
# 0  34.5      0      0   330911   7.8292   NaN         2
# 1  47.0      1      0   363272   7.0000   NaN         0
# 2  62.0      0      0   240276   9.6875   NaN         2
# 3  27.0      0      0   315154   8.6625   NaN         0
# 4  22.0      1      1  3101298  12.2875   NaN         0

# %%
# Let's Go for predictive model
# We will use Logistic regerssion for prediction
from sklearn import cross_validation as cv
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# initialize algorithim
algo_ = LogisticRegression(random_state=1)
# Compute the accuracy score for all the cross validation folds.  (much simpler than what we did before!)
scores = cv.cross_val_score(algo_,df[predictors_cols],df['Survived'],cv=5)
scores.mean()
# Out:
# E:\Anaconda\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 0.78905059140991862

# %%
# Support Vector Machines
svc_obj = SVC(kernel='linear')
svc_scores = cv.cross_val_score(svc_obj,df[predictors_cols],df['Survived'],cv=5)
svc_scores.mean()
# Out:
# 0.78783234336494212

# %%
algo = LogisticRegression(random_state=1)
X_train = df[predictors_cols]
Y_train = df['Survived']
X_test = test_df[predictors_cols]
#train the algorithim using all the train data
algo.fit(X_train,Y_train)
predictions = algo.predict(X_test)

submission = pd.DataFrame({
        "PassengerId": test_df["PassengerId"],
        "Survived": predictions
    })

submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
submission.to_csv("Result_data", sep='\t', encoding='utf-8')
